# %%
dbutils.help()

# %%
# %sql
SHOW CATALOGS

# %%
dbutils.fs.ls('/Volumes/batch24/test/bronze/csv/')

# %%
files = dbutils.fs.ls('/Volumes/batch24/test/bronze/csv/')
file_names = [f.name for f in files]
display(file_names)

# %%
path=r'/Volumes/batch24/test/bronze/csv/titanic.csv'
df=spark.read.option("header",True).option("inferSchema", "true").csv(path)
display(df)

# %%
#select specific colums
#use * for select All column
df1=df.select('*')
display(df1)

# %%
#rename column 
df2=df.withColumnRenamed('Name','FullName')
display(df2)

# %%
# df3 = df.toDF(*[col.replace(" ", "").lower() for col in df.columns])
# display(df3)

for col_name in df.columns:
    df = df.withColumnRenamed(col_name, col_name.replace(" ", "").lower())
display(df)

# %%
# ADD COLUMn in dataframe with consatnt value
from pyspark.sql.functions import *
df=df3.withColumn('persondata',lit('person'))
display(df)

# %%
#add two column in one column

from pyspark.sql.functions import concat_ws

df = df.withColumn(
    'sex_age',
    concat_ws(
        ' ',
        df['sex'],
        df['age']
    )
)
display(df)

# %%
from pyspark.sql.functions import split

# Assuming 'fullname' column contains values like "John Doe"
df = df.withColumn('first_name', split(df['fullname'], ' ').getItem(0)) \
       .withColumn('last_name', split(df['fullname'], ' ').getItem(1))
display(df)

# %%
from pyspark.sql.functions import split

# Assuming 'fullname' column contains values like "John Doe"
df = df.withColumn('first_name', split(df['fullname'], ' ').getItem(0)) \
       .withColumn('last_name', split(df['fullname'], ' ').getItem(1))
display(df)

# %%
from pyspark.sql.functions import col

df = df.withColumn('age', col('age') + 3)
display(df)

# %%
df = df.dropDuplicates()
display(df)
